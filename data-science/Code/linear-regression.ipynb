# %% [markdown]
# Learning linear regression using some code

# %%
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

import statsmodels.api as sm
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       2 import numpy as np
#       4 import matplotlib.pyplot as plt
# ----> 6 from sklearn.linear_model import LinearRegression
#       8 import statsmodels.api as sm
#
# File ~/Desktop/interview-prep/.venv/lib/python3.11/site-packages/sklearn/linear_model/__init__.py:12
#      10 from ._base import LinearRegression
#      11 from ._bayes import ARDRegression, BayesianRidge
# ---> 12 from ._coordinate_descent import (
#      13     ElasticNet,
#      14     ElasticNetCV,
#      15     Lasso,
#      16     LassoCV,
#      17     MultiTaskElasticNet,
#      18     MultiTaskElasticNetCV,
#      19     MultiTaskLasso,
#      20     MultiTaskLassoCV,
#      21     enet_path,
#      22     lasso_path,
#      23 )
#      24 from ._glm import GammaRegressor, PoissonRegressor, TweedieRegressor
#      25 from ._huber import HuberRegressor
#
# File ~/Desktop/interview-prep/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:44
#      33 from ..utils.validation import (
#      34     _check_sample_weight,
#      35     check_consistent_length,
#    (...)     40     validate_data,
#      41 )
#      43 # mypy error: Module 'sklearn.linear_model' has no attribute '_cd_fast'
# ---> 44 from . import _cd_fast as cd_fast  # type: ignore[attr-defined]
#      45 from ._base import LinearModel, _pre_fit, _preprocess_data
#      48 def _set_order(X, y, order="C"):
#
# File <frozen importlib._bootstrap>:405, in parent(self)
#
# KeyboardInterrupt:
